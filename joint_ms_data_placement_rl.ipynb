# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/63.1 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.11)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2024.12.14)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.6 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.5.0+cu121.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.5.0+cu121.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.5.0%2Bcu121/pyg_lib-0.4.0%2Bpt25cu121-cp311-cp311-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.5 MB/s eta 0:00:00
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.5.0%2Bcu121/torch_scatter-2.1.2%2Bpt25cu121-cp311-cp311-linux_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 65.6 MB/s eta 0:00:00
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.5.0%2Bcu121/torch_sparse-0.6.18%2Bpt25cu121-cp311-cp311-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 34.8 MB/s eta 0:00:00
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.5.0%2Bcu121/torch_cluster-1.6.3%2Bpt25cu121-cp311-cp311-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 46.3 MB/s eta 0:00:00
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.5.0%2Bcu121/torch_spline_conv-1.2.2%2Bpt25cu121-cp311-cp311-linux_x86_64.whl (994 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.8/994.8 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from torch_sparse) (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt25cu121 torch_cluster-1.6.3+pt25cu121 torch_scatter-2.1.2+pt25cu121 torch_sparse-0.6.18+pt25cu121 torch_spline_conv-1.2.2+pt25cu121

# %%
# !pip install --upgrade torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-2.5.0+cu121.html

# %%
import numpy as np
import networkx as nx
import gym
from gym import spaces
import torch
import random
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from pyomo.environ import *
from torch_geometric.utils.convert import from_networkx
from torch_geometric.nn import GCNConv
from collections import deque
import torch as T
import torch.nn.functional as F
import os
import numpy as np
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# Out:
# /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_scatter/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_cluster/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_spline_conv/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(
# /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/mohammeddhiyaeddinegouaouri/.conda/envs/phd/lib/python3.10/site-packages/torch_sparse/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
torch.__version__
# Out:
# '2.5.1'

# %%
num_microservices = 10
num_edge_servers = 10

BLOCK_SIZE = 1 # For 1GB

microservice_graph = nx.DiGraph()
edge_network = nx.erdos_renyi_graph(num_edge_servers, 0.5, seed=123, directed=False)

for m in range(num_microservices):
    microservice_graph.add_node(m, requested_cpu=random.randint(100, 500), requested_memory=random.randint(512, 1024), requested_disk=random.randint(2*BLOCK_SIZE, 4*BLOCK_SIZE))

# Add edges ensuring no cycles (DAG)
possible_edges = [(i, j) for i in range(num_microservices) for j in range(i + 1, num_microservices)]
for _ in range(num_microservices * 2):  # Add twice the number of nodes as edges
    if not possible_edges:
        break
    m1, m2 = random.choice(possible_edges)
    possible_edges.remove((m1, m2))
    bandwidth = random.randint(1, 10)
    microservice_graph.add_edge(m1, m2, bw_min=bandwidth)


for n in range(num_edge_servers):
    # Update node attr
    edge_network.add_node(n, available_cpu=random.randint(1000, 4000), available_memory=random.randint(4096, 2 * 4096), available_disk=random.randint(4*BLOCK_SIZE, 16*BLOCK_SIZE))

for n1, n2 in edge_network.edges():
    # n1, n2 = random.sample(range(num_edge_servers), 2)
    # Update edge attr
    bandwidth = random.randint(10, 100)
    edge_network.add_edge(n1, n2, bw=bandwidth, reverse_bw=1/bandwidth)

# %%
# Plotting Microservice Graph
plt.figure(figsize=(16, 8))

# Microservice Graph
plt.subplot(1, 2, 1)
pos_ms = nx.spring_layout(microservice_graph)
nx.draw(microservice_graph, pos_ms, with_labels=True, node_color='skyblue', node_size=1200)
labels_ms = {node: f"CPU: {microservice_graph.nodes[node]['requested_cpu']}\nMem: {microservice_graph.nodes[node]['requested_memory']}\nDisk: {microservice_graph.nodes[node]['requested_disk']}" for node in microservice_graph.nodes}
nx.draw_networkx_labels(microservice_graph, pos_ms, labels=labels_ms, font_size=8)

edge_labels_ms = {(u, v): f"BW: {data['bw_min']}" for u, v, data in microservice_graph.edges(data=True)}
nx.draw_networkx_edge_labels(microservice_graph, pos_ms, edge_labels=edge_labels_ms, font_size=8)
plt.title("Microservice Graph (Demands)")

# Edge Network Graph
plt.subplot(1, 2, 2)
pos_edge = nx.spring_layout(edge_network)
nx.draw(edge_network, pos_edge, with_labels=True, node_color='lightgreen', node_size=1200)
labels_edge = {node: f"CPU: {edge_network.nodes[node]['available_cpu']}\nMem: {edge_network.nodes[node]['available_memory']}\nDisk: {edge_network.nodes[node]['available_disk']}" for node in edge_network.nodes}
nx.draw_networkx_labels(edge_network, pos_edge, labels=labels_edge, font_size=8)

edge_labels_edge = {(u, v): f"BW: {data['bw']}" for u, v, data in edge_network.edges(data=True)}
nx.draw_networkx_edge_labels(edge_network, pos_edge, edge_labels=edge_labels_edge, font_size=8)
plt.title("Edge Network Graph (Capacities)")

plt.tight_layout()
plt.show()

# %%
import torch
import random
import networkx as nx
from torch_geometric.utils import from_networkx

class MicroservicePlacementEnv:
    def __init__(self, edge_network, num_microservices):
        self.edge_network = edge_network
        self._edge_network = edge_network

        self.num_edge_servers = len(self.edge_network.nodes)
        self.num_microservices = num_microservices

        self.max_disk_blocks = 10
        self._is_done = False

    def reset(self):
        # Reinitialize the graphs
        self.edge_network = self._edge_network
        return self._get_observation()

    def step(self, action):
        """
        Take a step in the environment.
        Args:
            action: A tuple containing:
                - placement_decisions: A tensor of edge server indices where each microservice is placed.
                - disk_allocations: A tensor of disk blocks allocated per edge server for each microservice.

        Returns:
            observation: The updated state of the environment.
            reward: The reward for the current action.
            done: Whether the episode is finished.
            info: Additional information for debugging.
        """
        placement_decisions, disk_allocations = action  # generated by the agent

        # Calculate the reward based on placement and disk allocation
        reward = self._calculate_reward(placement_decisions, disk_allocations)

        # Update the environment and generate the next observation
        observation = self._get_observation()
        done = self._is_done
        info = {}

        return observation, reward, done, info

    def _calculate_reward(self, x, y):
        # print(x)
        # print(y)
        # Calculate L_ms
        L_ms = 0
        for m1, m2, data in self.microservice_graph.edges(data=True):
            for n1 in range(self.num_edge_servers):
                for n2 in range(self.num_edge_servers):
                    path_cost = (
                        nx.shortest_path_length(
                            self.edge_network, source=n1, target=n2, weight="reverse_bw"
                        )
                        if n1 != n2
                        else 0
                    )
                    L_ms += x[m1, n1] * x[m2, n2] * path_cost

        # Calculate L_vol
        L_vol = 0
        for m in range(self.num_microservices):
            for n1 in range(self.num_edge_servers):
                for n2 in range(self.num_edge_servers):
                    path_cost = (
                        nx.shortest_path_length(
                            self.edge_network, source=n1, target=n2, weight="reverse_bw"
                        )
                        if n1 != n2
                        else 0
                    )
                    L_vol += x[m, n1] * y[m, n2] * path_cost

        # Constraint violations
        constraint_violations = 0

        # Validate disk allocation constraints
        for ms_id in range(self.num_microservices):
            if torch.sum(y[ms_id]) > self.max_disk_blocks:
                constraint_violations += 1

        # Placement constraint: Each microservice must be assigned to one edge server
        for m in range(self.num_microservices):
            if torch.sum(x[m, :]) != 1:
                constraint_violations += 1

        # Resource constraints per edge server
        for n in range(self.num_edge_servers):
            cpu_usage = sum(
                x[m, n] * self.microservice_graph.nodes[m]["requested_cpu"]
                for m in range(self.num_microservices)
            )
            memory_usage = sum(
                x[m, n] * self.microservice_graph.nodes[m]["requested_memory"]
                for m in range(self.num_microservices)
            )
            disk_usage = sum(y[m, n] for m in range(self.num_microservices))

            if cpu_usage > self.edge_network.nodes[n]["available_cpu"]:
                self._is_done =  True
                constraint_violations += 1
            if memory_usage > self.edge_network.nodes[n]["available_memory"]:
                self._is_done =  True
                constraint_violations += 1
                
            if disk_usage > self.edge_network.nodes[n]["available_disk"]:
                self._is_done =  True
                constraint_violations += 1
                

        # Disk demand constraint
        for m in range(self.num_microservices):
            if not torch.isclose(
                torch.sum(y[m, :]), torch.tensor(self.microservice_graph.nodes[m]["requested_disk"])
            ):
                constraint_violations += 1

        # Penalty for constraint violations
        penalty = 100 * constraint_violations
        # Reduce resources based on the action
        if not self._is_done:
            for ms in range(self.num_microservices):
                cpu_demand, memory_demand = self.microservice_graph.nodes[ms]['requested_cpu'], microservice_graph.nodes[ms]['requested_memory']
                ms_placed_on = x.argmax(dim=1).cpu().item()
                data_placed_on = torch.nonzero(y[ms] > 0).squeeze(-1).cpu().detach()
                print(f"Updating ms placed on {ms_placed_on}")
                
                self.edge_network.nodes[ms_placed_on]['available_cpu'] -= cpu_demand
                self.edge_network.nodes[ms_placed_on]['available_memory'] -= memory_demand
                for e in data_placed_on:
                    print(f"Updating data placed on {e}")
                    self.edge_network.nodes[e]['available_disk'] -= y[ms, e]
                
        # Reward is the negative of the cost and penalty
        reward = -(L_ms + L_vol + penalty)
        return reward

    def _get_observation(self):
        # Generate new microservice graph
        microservice_graph = nx.DiGraph()

        for m in range(self.num_microservices):
            microservice_graph.add_node(
                m,
                requested_cpu=random.randint(100, 500),
                requested_memory=random.randint(512, 1024),
                requested_disk=random.randint(2, 4),
            )

        # Add edges ensuring no cycles (DAG)
        possible_edges = [
            (i, j)
            for i in range(self.num_microservices)
            for j in range(i + 1, self.num_microservices)
        ]
        for _ in range(self.num_microservices * 2):
            if not possible_edges:
                break
            m1, m2 = random.choice(possible_edges)
            possible_edges.remove((m1, m2))
            bandwidth = random.randint(1, 10)
            microservice_graph.add_edge(m1, m2, bw_min=bandwidth)

        self.microservice_graph = microservice_graph

        ms_graph_data = self._ms_graph_to_torch(self.microservice_graph)
        edge_network_data = self._edge_network_to_torch(self.edge_network)


        return {
            "ms_graph_data": ms_graph_data,
            "edge_network_data": edge_network_data,
        }

    def _ms_graph_to_torch(self, G):
        data = from_networkx(G)
        data.x = torch.stack(
            [torch.tensor(data.requested_cpu), torch.tensor(data.requested_memory), torch.tensor(data.requested_disk)]
        ).T
        return data

    def _edge_network_to_torch(self, G):
        data = from_networkx(G)
        data.x = torch.stack(
            [
                torch.tensor(data.available_cpu),
                torch.tensor(data.available_memory),
                torch.tensor(data.available_disk),
            ]
        ).T
        return data

    def plot(self):
        microservice_graph = self.microservice_graph
        edge_network = self.edge_network
        
        plt.figure(figsize=(16, 8))
        
        # Microservice Graph
        plt.subplot(1, 2, 1)
        pos_ms = nx.spring_layout(microservice_graph)
        nx.draw(microservice_graph, pos_ms, with_labels=True, node_color='skyblue', node_size=1200)
        labels_ms = {node: f"CPU: {microservice_graph.nodes[node]['requested_cpu']}\nMem: {microservice_graph.nodes[node]['requested_memory']}\nDisk: {microservice_graph.nodes[node]['requested_disk']}" for node in microservice_graph.nodes}
        nx.draw_networkx_labels(microservice_graph, pos_ms, labels=labels_ms, font_size=8)
        
        edge_labels_ms = {(u, v): f"BW: {data['bw_min']}" for u, v, data in microservice_graph.edges(data=True)}
        nx.draw_networkx_edge_labels(microservice_graph, pos_ms, edge_labels=edge_labels_ms, font_size=8)
        plt.title("Microservice Graph (Demands)")
        
        # Edge Network Graph
        plt.subplot(1, 2, 2)
        pos_edge = nx.spring_layout(edge_network)
        nx.draw(edge_network, pos_edge, with_labels=True, node_color='lightgreen', node_size=1200)
        labels_edge = {node: f"CPU: {edge_network.nodes[node]['available_cpu']}\nMem: {edge_network.nodes[node]['available_memory']}\nDisk: {edge_network.nodes[node]['available_disk']}" for node in edge_network.nodes}
        nx.draw_networkx_labels(edge_network, pos_edge, labels=labels_edge, font_size=8)
        
        edge_labels_edge = {(u, v): f"BW: {data['bw']}" for u, v, data in edge_network.edges(data=True)}
        nx.draw_networkx_edge_labels(edge_network, pos_edge, edge_labels=edge_labels_edge, font_size=8)
        plt.title("Edge Network Graph (Capacities)")
        
        plt.tight_layout()
        plt.show()

# %%
class GNNEncoder(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GNNEncoder, self).__init__()
        self.output_dim = output_dim
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, x, edge_index):
        x = x.to(torch.float)
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return x

    def get_embedding_dim(self,):
        # TODO: Implement this
        return self.output_dim

# %%
class ReplayBuffer(): # ReplayBuffer class initializes an empty deque with a maximum length of buffer_size
    def __init__(self, buffer_size):
        self.buffer_size = buffer_size
        self.count = 0
        self.buffer = deque()

    def add(self, s, a, r,s_next): # The add method is used to add the current state, the action taken, the reward received, the next state
        experience = (s, a, r,s_next)
        if self.count < self.buffer_size:
            self.buffer.append(experience)
            self.count += 1
        else:
            self.buffer.popleft()
            self.buffer.append(experience)

    def size(self):
        return self.count

    def sample_batch(self, batch_size): #he sample method is used to randomly sample a batch of experiences from the buffer of size batch_size
        minibatch = []
        if self.count < batch_size:
            minibatch = random.sample(self.buffer, self.count)
        else:
            minibatch = random.sample(self.buffer, batch_size)

        batch_s = [d[0] for d in minibatch]
        batch_a = [d[1] for d in minibatch]
        batch_r = [d[2] for d in minibatch]
        batch_s_next = [d[3] for d in minibatch]
        return batch_s, batch_a, batch_r,batch_s_next  # It returns five lists, one for each component of the experience tuple.

    def clear(self):  # the clear method clears the buffer
        self.buffer.clear()
        self.count = 0

# %%
class CriticNetwork(nn.Module):
    def __init__(self,
                 num_microservices,
                 num_edge_servers,
                 ms_gnn,
                 edge_network_gnn,
                 lr=5e-4,
                 input_dims=None,
                 fc1_dims=512,
                 fc2_dims=128,
                 fc3_dims=64,
                 name=None,
                 checkpoint_dir="/content/drive/MyDrive/models/"):
        super(CriticNetwork, self).__init__()
        self.input_dims = input_dims  # State input dimensions
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.fc3_dims = fc3_dims
        self.num_microservices = num_microservices
        self.num_edge_servers = num_edge_servers
        self.ms_gnn = ms_gnn
        self.edge_network_gnn = edge_network_gnn
        self.name = name
        self.checkpoint_dir = checkpoint_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name + "_ddpg")

        # Fully connected layers for state
        self.fc1 = nn.Linear(self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.fc3_dims)

        # Batch normalization
        self.bn1 = nn.LayerNorm(self.fc1_dims)
        self.bn2 = nn.LayerNorm(self.fc2_dims)
        self.bn3 = nn.LayerNorm(self.fc3_dims)

        # Fully connected layers for action
        # Action dimensions = placement + allocation
        action_dims = self.num_microservices * self.num_edge_servers * 2  # Placement + allocation
        self.action_fc = nn.Linear(action_dims, self.fc3_dims)

        # Output layer for Q-value
        self.q = nn.Linear(self.fc3_dims, 1)

        # Parameter initialization
        self._init_weights()

        # Optimizer
        self.optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=0.01)

        # Device
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def _init_weights(self):
        """Initialize weights for all layers."""
        f1 = 1. / np.sqrt(self.fc1.weight.data.size()[0])
        self.fc1.weight.data.uniform_(-f1, f1)
        self.fc1.bias.data.uniform_(-f1, f1)

        f2 = 1. / np.sqrt(self.fc2.weight.data.size()[0])
        self.fc2.weight.data.uniform_(-f2, f2)
        self.fc2.bias.data.uniform_(-f2, f2)

        f3 = 1. / np.sqrt(self.fc3.weight.data.size()[0])
        self.fc3.weight.data.uniform_(-f3, f3)
        self.fc3.bias.data.uniform_(-f3, f3)

        f4 = 1. / np.sqrt(self.action_fc.weight.data.size()[0])
        self.action_fc.weight.data.uniform_(-f4, f4)
        self.action_fc.bias.data.uniform_(-f4, f4)

        f_out = 0.003
        self.q.weight.data.uniform_(-f_out, f_out)
        self.q.bias.data.uniform_(-f_out, f_out)

    def forward(self, states, actions):
        """
        Forward pass to compute Q-values for a batch of state-action pairs.
    
        Args:
            states (list of dict): A batch of state dictionaries. Each dictionary contains:
                - "ms_graph_data": Microservice graph data (torch_geometric.data.Data).
                - "edge_network_data": Edge network graph data (torch_geometric.data.Data).
            actions (torch.Tensor): A batch of action tensors 
                (batch_size, num_microservices * num_edge_servers * 2).
    
        Returns:
            torch.Tensor: Q-values of the state-action pairs (batch_size, 1).
        """
        batch_size = len(states)
    
        # Initialize lists to hold embeddings for the batch
        ms_embeddings = []
        edge_embeddings = []
    
        # Process each state in the batch
        for state in states:
            ms_graph = state["ms_graph_data"]
            edge_network = state["edge_network_data"]
    
            # Compute embeddings for the current state's microservice graph and edge network graph
            ms_embedding = self.ms_gnn(ms_graph.x, ms_graph.edge_index).mean(dim=0, keepdim=True)
            edge_embedding = self.edge_network_gnn(edge_network.x, edge_network.edge_index).mean(dim=0, keepdim=True)
    
            ms_embeddings.append(ms_embedding)
            edge_embeddings.append(edge_embedding)
    
        # Concatenate embeddings for the entire batch
        ms_embeddings = torch.cat(ms_embeddings, dim=0)  # Shape: (batch_size, embedding_dim)
        edge_embeddings = torch.cat(edge_embeddings, dim=0)  # Shape: (batch_size, embedding_dim)
    
        # Concatenate microservice and edge network embeddings for each state
        embeddings = torch.cat((ms_embeddings, edge_embeddings), dim=-1)  # Shape: (batch_size, input_dims)
    
        # Process state
        state_value = self.fc1(embeddings)
        state_value = self.bn1(state_value)
        state_value = F.relu(state_value)
    
        state_value = self.fc2(state_value)
        state_value = self.bn2(state_value)
        state_value = F.relu(state_value)
    
        state_value = self.fc3(state_value)
        state_value = self.bn3(state_value)
        state_value = F.relu(state_value)
    
        flattened_actions = self.process_actions(actions)
        action_value = self.action_fc(flattened_actions)
        action_value = F.relu(action_value)
    
        # Combine state and action values
        state_action_value = F.relu(state_value + action_value)
    
        # Output Q-value
        q_value = self.q(state_action_value)
    
        return q_value


    # Assuming actions is a list of tuples [(placement_matrix, allocation_matrix), ...]
    def process_actions(self, actions):
        flattened_actions = []
        if isinstance(actions, tuple):
            actions = [actions]
        for placement_matrix, allocation_matrix in actions:
            # Flatten each matrix
            flattened_placement = placement_matrix.view(placement_matrix.size(0), -1)  # (batch_size, num_microservices * num_edge_servers)
            flattened_allocation = allocation_matrix.view(allocation_matrix.size(0), -1)  # (batch_size, num_microservices * num_edge_servers)
    
            # Concatenate the flattened matrices
            combined_action = torch.cat((flattened_placement, flattened_allocation), dim=-1)  # (batch_size, action_dims)
            flattened_actions.append(combined_action)
    
        # Stack all processed actions into a single tensor
        flattened_actions = torch.cat(flattened_actions, dim=0)  # (batch_size, action_dims)
    
        return flattened_actions.reshape(64, 200)


    def save_checkpoint(self):
        print(" ... saving checkpoint ...")
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print(" ... loading checkpoint ...")
        self.load_state_dict(T.load(self.checkpoint_file))

# %%
class ActorNetwork(nn.Module):
    def __init__(self,
                 num_microservices,
                 num_edge_servers,
                 ms_gnn,
                 edge_network_gnn,
                 max_disk_blocks,
                 lr=5e-4,
                 input_dims=None,
                 fc1_dims=600,
                 fc2_dims=400,
                 fc3_dims=100,
                 name=None,
                 checkpoint_dir="/content/drive/MyDrive/models/tests"
        ):
        super(ActorNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.fc3_dims = fc3_dims
        self.num_microservices = num_microservices
        self.num_edge_servers = num_edge_servers
        self.ms_gnn = ms_gnn
        self.edge_network_gnn = edge_network_gnn
        self.max_disk_blocks = max_disk_blocks
        self.name = name
        self.checkpoint_dir = checkpoint_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name + "_ddpg")

        self.fc1 = nn.Linear(self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.fc3_dims)


        self.bn1 = nn.LayerNorm(self.fc1_dims)
        self.bn2 = nn.LayerNorm(self.fc2_dims)
        self.bn3 = nn.LayerNorm(self.fc3_dims)

         # Output layers
        self.placement_output = nn.Linear(self.fc3_dims, self.num_microservices * self.num_edge_servers)
        self.data_allocation_output = nn.Linear(self.fc3_dims, self.num_microservices * self.num_edge_servers)


        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        self.fc1.weight.data.uniform_(-f1, f1)
        self.fc1.bias.data.uniform_(-f1, f1)

        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        self.fc2.weight.data.uniform_(-f2, f2)
        self.fc2.bias.data.uniform_(-f2, f2)

        f3 = 1./np.sqrt(self.fc3.weight.data.size()[0])
        self.fc3.weight.data.uniform_(-f3, f3)
        self.fc3.bias.data.uniform_(-f3, f3)

        f_out = 0.003
        self.placement_output.weight.data.uniform_(-f_out, f_out)
        self.placement_output.bias.data.uniform_(-f_out, f_out)

        self.data_allocation_output.weight.data.uniform_(-f_out, f_out)
        self.data_allocation_output.bias.data.uniform_(-f_out, f_out)

        self.optimizer = optim.Adam(self.parameters(), lr=lr,
                                    weight_decay=0.01)

        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)



    def forward(self, states):
        """
        Forward pass to generate placement and allocation decisions for a batch of states.
    
        Args:
            states (list of dict): A batch of state dictionaries. Each dictionary contains:
                - "ms_graph_data": Microservice graph data (torch_geometric.data.Data).
                - "edge_network_data": Edge network graph data (torch_geometric.data.Data).
    
        Returns:
            placements (torch.Tensor): Placement decisions for the batch 
                (batch_size, num_microservices, num_edge_servers).
            allocations (torch.Tensor): Allocation decisions for the batch 
                (batch_size, num_microservices, num_edge_servers).
        """
        batch_size = len(states)
    
        # Initialize lists to hold embeddings for the batch
        ms_embeddings = []
        edge_embeddings = []
    
        # Process each state in the batch
        for state in states:
            ms_graph = state["ms_graph_data"]
            edge_network = state["edge_network_data"]
    
            # Compute embeddings for the current state's microservice graph and edge network graph
            ms_embedding = self.ms_gnn(ms_graph.x, ms_graph.edge_index).mean(dim=0, keepdim=True)
            edge_embedding = self.edge_network_gnn(edge_network.x, edge_network.edge_index).mean(dim=0, keepdim=True)
    
            ms_embeddings.append(ms_embedding)
            edge_embeddings.append(edge_embedding)
    
        # Concatenate embeddings for the entire batch
        ms_embeddings = torch.cat(ms_embeddings, dim=0)  # Shape: (batch_size, embedding_dim)
        edge_embeddings = torch.cat(edge_embeddings, dim=0)  # Shape: (batch_size, embedding_dim)
    
        # Concatenate microservice and edge network embeddings for each state
        embeddings = torch.cat((ms_embeddings, edge_embeddings), dim=-1)  # Shape: (batch_size, input_dims)
    
        # Pass through fully connected layers
        x = self.fc1(embeddings)
        x = self.bn1(x)
        x = F.relu(x)
    
        x = self.fc2(x)
        x = self.bn2(x)
        x = F.relu(x)
    
        x = self.fc3(x)
        x = self.bn3(x)
        x = F.relu(x)
    
        # Placement decisions
        placement_logits = self.placement_output(x)  # Shape: (batch_size, num_microservices * num_edge_servers)
        placement_logits = placement_logits.view(batch_size, self.num_microservices, self.num_edge_servers)
        placements = F.softmax(placement_logits, dim=-1)  # Probability distribution over edge servers
    
        # Data allocation decisions
        allocation_logits = self.data_allocation_output(x)  # Shape: (batch_size, num_microservices * num_edge_servers)
        allocation_logits = allocation_logits.view(batch_size, self.num_microservices, self.num_edge_servers)
        allocations = F.relu(allocation_logits)  # Non-negative allocation for disk blocks
    
        # Normalize allocations to satisfy max_disk_blocks constraint
        allocation_sum = allocations.sum(dim=-1, keepdim=True)  # Sum over edge servers for each microservice
        allocations = (allocations / (allocation_sum + 1e-6)) * self.max_disk_blocks  # Normalize and scale
        allocations = torch.round(allocations).int()  # Convert to integers
    
        return placements, allocations

    def save_checkpoint(self):
        print(" ... saving checkpoint ...")
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print(" ... loading checkpoint ...")
        self.load_state_dict(T.load(self.checkpoint_file))

# %%
class DDPGAgent():
    EPS_START = 0.9
    EPS_END = 0.05
    EPS_DECAY = 1000

    def __init__(self,
                 env,
                 gnn_input_dim=3,  # Features per node
                 gnn_hidden_dim=128,
                 gnn_output_dim=64,
                 gamma=0.95,
                 max_size=1000000,
                 fc1_dims=512,
                 fc2_dims=128,
                 batch_size=64,
                 max_disk_blocks=10,
                 tau=0.8,
        ):
        self.gamma = gamma
        self.tau = tau
        self.batch_size = batch_size
        self.max_disk_blocks = max_disk_blocks
        self.env = env
        self.memory = ReplayBuffer(max_size)

        self.num_microservices = self.env.num_microservices
        self.num_edge_servers = self.env.num_edge_servers

        self.ms_gnn = GNNEncoder(gnn_input_dim, gnn_hidden_dim, gnn_output_dim)
        self.edge_network_gnn = GNNEncoder(gnn_input_dim, gnn_hidden_dim, gnn_output_dim)

        # Actor and Critic Networks
        self.actor = ActorNetwork(num_microservices, num_edge_servers, self.ms_gnn, self.edge_network_gnn, max_disk_blocks, fc1_dims, fc2_dims, name='actor')
        self.critic = CriticNetwork(num_microservices, num_edge_servers, self.ms_gnn, self.edge_network_gnn, fc1_dims, fc2_dims, name='critic')

        self.target_actor = ActorNetwork(num_microservices, num_edge_servers, self.ms_gnn, self.edge_network_gnn, max_disk_blocks, fc1_dims, fc2_dims, name='target_actor')
        self.target_critic = CriticNetwork(num_microservices, num_edge_servers, self.ms_gnn, self.edge_network_gnn, fc1_dims, fc2_dims, name='target_critic')

        self.update_network_parameters(tau=1)
        self.steps_done = 0

    def choose_action(self, observation):
        """
        Select an action using epsilon-greedy strategy.
        """
        eps_threshold = self.EPS_END + (self.EPS_START - self.EPS_END) * \
            np.exp(-1. * self.steps_done / self.EPS_DECAY)
        self.steps_done += 1
        if random.random() > eps_threshold:
            self.actor.eval()
            # state = torch.tensor([observation], dtype=torch.float).to(self.actor.device)
            placement, allocation = self.actor.forward(observation)
            self.actor.train()
            placement =  placement.cpu().detach()[0]
            allocation = allocation.cpu().detach()[0]
            action = (placement, allocation)
            action = self.fix_action(action)
            # print(f"Placement actor")
            return action
        else:
            # Random action
            action = self.sample_random_action()
            action = self.fix_action(action)
            return action

    def sample_random_action(self):
        """
        Sample a random valid action using PyTorch.
        """
        # Random placement decisions
        placement = torch.distributions.Dirichlet(torch.ones(self.num_edge_servers)).sample((self.num_microservices,))
    
        # Random disk allocation
        allocation = torch.randint(
            0, self.max_disk_blocks, (self.num_microservices, self.num_edge_servers)
        )
        
        return placement, allocation

    def fix_action(self, action):
        original_placement, allocation = action
        placement = torch.zeros_like(original_placement, dtype=torch.float32)
        placement[torch.arange(original_placement.size(0)), torch.argmax(original_placement, dim=1)] = 1.0
        return placement, allocation

    def remember(self, state, action, reward, state_):
        """
        Store a transition in memory.
        """
        self.memory.add(state, action, reward, state_)

    def learn(self):
        """
        Perform a single learning step.
        """
        if self.memory.size() < self.batch_size:
            return

        states, actions, rewards, states_ = self.memory.sample_batch(self.batch_size)
        # print(actions, rewards)
        # Convert to tensors
        # states = torch.tensor(states, dtype=torch.float).to(self.actor.device)
        # actions = torch.tensor(actions, dtype=torch.float).to(self.actor.device)
        rewards = torch.tensor(rewards, dtype=torch.float).to(self.actor.device)
        # states_ = torch.tensor(states_, dtype=torch.float).to(self.actor.device)
        rewards = rewards.unsqueeze(1)

        # Target actions and Q-values
        target_actions = self.target_actor.forward(states_)
        critic_value_ = self.target_critic.forward(states_, target_actions)
        critic_value = self.critic.forward(states, actions)

        # Compute target value
        target = rewards + self.gamma * critic_value_
        target = target.view(self.batch_size, 1)

        # Update critic
        self.critic.optimizer.zero_grad()
        critic_loss = F.mse_loss(critic_value, target)
        critic_loss.backward()
        torch.nn.utils.clip_grad_value_(self.critic.parameters(), 100)
        self.critic.optimizer.step()

        # Update actor
        self.actor.optimizer.zero_grad()
        actor_loss = -self.critic.forward(states, self.actor.forward(states)).mean()
        actor_loss.backward()
        torch.nn.utils.clip_grad_value_(self.actor.parameters(), 100)
        self.actor.optimizer.step()

        # Update target networks
        self.update_network_parameters()

        return critic_loss.item(), actor_loss.item()

    def update_network_parameters(self, tau=None):
        """
        Soft update of target network parameters.
        """
        if tau is None:
            tau = self.tau

        # Update critic
        for target_param, param in zip(self.target_critic.parameters(), self.critic.parameters()):
            target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

        # Update actor
        for target_param, param in zip(self.target_actor.parameters(), self.actor.parameters()):
            target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

    def save(self):
        """
        Save network parameters.
        """
        self.actor.save_checkpoint()
        self.target_actor.save_checkpoint()
        self.critic.save_checkpoint()
        self.target_critic.save_checkpoint()

    def load(self):
        """
        Load network parameters.
        """
        self.actor.load_checkpoint()
        self.target_actor.load_checkpoint()
        self.critic.load_checkpoint()
        self.target_critic.load_checkpoint()

# %%
env = MicroservicePlacementEnv(edge_network, num_microservices)
agent = DDPGAgent(env)

# %%
num_episodes = 10000
num_steps = 1000
batch_size = 256

# %%
rewards_history = []  # To track total rewards per episode
critic_losses = []  # To track critic loss per step
actor_losses = []  # To track actor loss per step

for episode in range(num_episodes):
    # Reset environment
    state = env.reset()
    ms_graph_data = state["ms_graph_data"]
    edge_network_data = state["edge_network_data"]

    total_reward = 0  # Track cumulative reward per episode

    for step in range(num_steps):
        # Select an action using the agent's policy
        with torch.no_grad():
            placement, allocation = agent.choose_action([{
                "ms_graph_data": ms_graph_data,
                "edge_network_data": edge_network_data,
            }])

        action = (placement, allocation)

        # Perform action in the environment
        next_state, reward, done, info = env.step(action)
        next_ms_graph_data = next_state["ms_graph_data"]
        next_edge_network_data = next_state["edge_network_data"]

        # Store the transition in replay buffer
        agent.remember({
            "ms_graph_data": ms_graph_data,
            "edge_network_data": edge_network_data,
        }, action, reward, {
            "ms_graph_data": next_ms_graph_data,
            "edge_network_data": next_edge_network_data,
        })

        # Update state
        ms_graph_data = next_ms_graph_data
        edge_network_data = next_edge_network_data
        total_reward += reward

        # Learn from experience
        if agent.memory.size() > batch_size:
            critic_loss, actor_loss = agent.learn()
            critic_losses.append(critic_loss)
            actor_losses.append(actor_loss)

        # Check if episode is done
        if done:
            break

    # Track episode rewards
    rewards_history.append(total_reward)

    # Log progress
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}")

    # Save models periodically
    # if (episode + 1) % 50 == 0:
    #     agent.save()
# Out:
# /tmp/ipykernel_364770/185145985.py:183: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   [torch.tensor(data.requested_cpu), torch.tensor(data.requested_memory), torch.tensor(data.requested_disk)]
# /tmp/ipykernel_364770/185145985.py:191: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data.available_cpu),
# /tmp/ipykernel_364770/185145985.py:192: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data.available_memory),
# /tmp/ipykernel_364770/185145985.py:193: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data.available_disk),
# Episode 1/10000, Total Reward: -3025.63
# Episode 2/10000, Total Reward: -3018.66
# Episode 3/10000, Total Reward: -3016.85
# Episode 4/10000, Total Reward: -3015.61
# Episode 5/10000, Total Reward: -3012.60
# Episode 6/10000, Total Reward: -3015.08
# Episode 7/10000, Total Reward: -3020.71
# Episode 8/10000, Total Reward: -3018.64
# Episode 9/10000, Total Reward: -1603.84
# Episode 10/10000, Total Reward: -3015.75
# Episode 11/10000, Total Reward: -3014.91
# Episode 12/10000, Total Reward: -3015.92
# Episode 13/10000, Total Reward: -3017.21
# Episode 14/10000, Total Reward: -3023.53
# Episode 15/10000, Total Reward: -3015.67
# Episode 16/10000, Total Reward: -3016.76
# Episode 17/10000, Total Reward: -3021.08
# Episode 18/10000, Total Reward: -3018.54
# Episode 19/10000, Total Reward: -3022.29
# Episode 20/10000, Total Reward: -3018.41
# Episode 21/10000, Total Reward: -3013.99
# Episode 22/10000, Total Reward: -3021.49
# Episode 23/10000, Total Reward: -3016.68
# Episode 24/10000, Total Reward: -3016.78
# Episode 25/10000, Total Reward: -1703.75
# Episode 26/10000, Total Reward: -3022.44
# Episode 27/10000, Total Reward: -3016.23
# Episode 28/10000, Total Reward: -3017.62
# Episode 29/10000, Total Reward: -3019.02
# Episode 30/10000, Total Reward: -3017.36
# Episode 31/10000, Total Reward: -3019.59
# Episode 32/10000, Total Reward: -3014.98
# Episode 33/10000, Total Reward: -3016.41
# Episode 34/10000, Total Reward: -3017.91
# Episode 35/10000, Total Reward: -3019.06
# Episode 36/10000, Total Reward: -3016.45
# Episode 37/10000, Total Reward: -1803.81
# Episode 38/10000, Total Reward: -1803.72
# Episode 39/10000, Total Reward: -3018.20
# Episode 40/10000, Total Reward: -3018.35
# Episode 41/10000, Total Reward: -1603.82
# Episode 42/10000, Total Reward: -3016.06
# Episode 43/10000, Total Reward: -3019.40
# Episode 44/10000, Total Reward: -3021.99
# Episode 45/10000, Total Reward: -1803.83
# Episode 46/10000, Total Reward: -3018.73
# Episode 47/10000, Total Reward: -3016.14
# Episode 48/10000, Total Reward: -1503.83
# Episode 49/10000, Total Reward: -3120.29
# Episode 50/10000, Total Reward: -3018.51
# Episode 51/10000, Total Reward: -3019.95
# Episode 52/10000, Total Reward: -3016.05
# Episode 53/10000, Total Reward: -3020.27
# Episode 54/10000, Total Reward: -3019.53
# Episode 55/10000, Total Reward: -3019.12
# Episode 56/10000, Total Reward: -3117.59
# Episode 57/10000, Total Reward: -3017.36
# Episode 58/10000, Total Reward: -3017.04
# Episode 59/10000, Total Reward: -3019.24
# Episode 60/10000, Total Reward: -3021.93
# Episode 61/10000, Total Reward: -3019.03
# Episode 62/10000, Total Reward: -3018.07
# Episode 63/10000, Total Reward: -3018.75
# Episode 64/10000, Total Reward: -1503.88
# Episode 65/10000, Total Reward: -3017.88
# Episode 66/10000, Total Reward: -3017.57
# Episode 67/10000, Total Reward: -3017.70
# Episode 68/10000, Total Reward: -3020.12
# Episode 69/10000, Total Reward: -3019.83
# Episode 70/10000, Total Reward: -3015.11
# Episode 71/10000, Total Reward: -3017.16
# Episode 72/10000, Total Reward: -3016.36
# Episode 73/10000, Total Reward: -3018.53
# Episode 74/10000, Total Reward: -3018.82
# Episode 75/10000, Total Reward: -3016.31
# Episode 76/10000, Total Reward: -3017.36
# Episode 77/10000, Total Reward: -3016.34
# Episode 78/10000, Total Reward: -1603.74
# Episode 79/10000, Total Reward: -3016.43
# Episode 80/10000, Total Reward: -3015.74
# Episode 81/10000, Total Reward: -3014.66
# Episode 82/10000, Total Reward: -3022.43
# Episode 83/10000, Total Reward: -3016.10
# Episode 84/10000, Total Reward: -3016.99
# Episode 85/10000, Total Reward: -3017.07
# Episode 86/10000, Total Reward: -3018.79
# Episode 87/10000, Total Reward: -3020.58
# Episode 88/10000, Total Reward: -3015.04
# Episode 89/10000, Total Reward: -1703.65
# Episode 90/10000, Total Reward: -3018.56
# Episode 91/10000, Total Reward: -1703.72
# Episode 92/10000, Total Reward: -3017.74
# Episode 93/10000, Total Reward: -1703.63
# Episode 94/10000, Total Reward: -3018.32
# Episode 95/10000, Total Reward: -3018.35
# Episode 96/10000, Total Reward: -3018.43
# Episode 97/10000, Total Reward: -3018.56
# Episode 98/10000, Total Reward: -3014.66
# Episode 99/10000, Total Reward: -3017.97
# Episode 100/10000, Total Reward: -3017.13
# Episode 101/10000, Total Reward: -3023.23
# Episode 102/10000, Total Reward: -3022.67
# Episode 103/10000, Total Reward: -3015.31
# Episode 104/10000, Total Reward: -3020.45
# Episode 105/10000, Total Reward: -3115.84
# Episode 106/10000, Total Reward: -3020.22
# Episode 107/10000, Total Reward: -3019.18
# Episode 108/10000, Total Reward: -3017.78
# Episode 109/10000, Total Reward: -3016.56
# Episode 110/10000, Total Reward: -3019.87
# Episode 111/10000, Total Reward: -3016.21
# Episode 112/10000, Total Reward: -3017.84
# Episode 113/10000, Total Reward: -3019.68
# Episode 114/10000, Total Reward: -3020.66
# Episode 115/10000, Total Reward: -3013.96
# Episode 116/10000, Total Reward: -3020.53
# Episode 117/10000, Total Reward: -3018.67
# Episode 118/10000, Total Reward: -3018.36
# Episode 119/10000, Total Reward: -3017.58
# Episode 120/10000, Total Reward: -3017.14
# Episode 121/10000, Total Reward: -3018.18
# Episode 122/10000, Total Reward: -1803.75
# Episode 123/10000, Total Reward: -3017.87
# Episode 124/10000, Total Reward: -1603.79
# Episode 125/10000, Total Reward: -1503.63
# Episode 126/10000, Total Reward: -3016.26
# Episode 127/10000, Total Reward: -3016.67
# Episode 128/10000, Total Reward: -3020.53
# Episode 129/10000, Total Reward: -1803.63
# Episode 130/10000, Total Reward: -3019.50
# Episode 131/10000, Total Reward: -3018.41
# Episode 132/10000, Total Reward: -1603.80
# Episode 133/10000, Total Reward: -1803.77
# Episode 134/10000, Total Reward: -3015.82
# Episode 135/10000, Total Reward: -1604.29
# Episode 136/10000, Total Reward: -3018.94
# Episode 137/10000, Total Reward: -3020.53
# Episode 138/10000, Total Reward: -3116.46
# Episode 139/10000, Total Reward: -3018.17
# Episode 140/10000, Total Reward: -3018.17
# Episode 141/10000, Total Reward: -3021.20
# Episode 142/10000, Total Reward: -1603.75
# Episode 143/10000, Total Reward: -1803.74
# Episode 144/10000, Total Reward: -3015.86
# Episode 145/10000, Total Reward: -3021.60
# Episode 146/10000, Total Reward: -3019.90
# Episode 147/10000, Total Reward: -1803.81
# Episode 148/10000, Total Reward: -3021.27
# Episode 149/10000, Total Reward: -3019.71
# Episode 150/10000, Total Reward: -3018.65
# Episode 151/10000, Total Reward: -3015.62
# Episode 152/10000, Total Reward: -3019.90
# Episode 153/10000, Total Reward: -3016.77
# Episode 154/10000, Total Reward: -3016.88
# Episode 155/10000, Total Reward: -3021.43
# Episode 156/10000, Total Reward: -3020.32
# Episode 157/10000, Total Reward: -3018.81
# Episode 158/10000, Total Reward: -1804.40
# Episode 159/10000, Total Reward: -3016.35
# Episode 160/10000, Total Reward: -1803.72
# Episode 161/10000, Total Reward: -3019.39
# Episode 162/10000, Total Reward: -3016.65
# Episode 163/10000, Total Reward: -3019.13
# Episode 164/10000, Total Reward: -3015.17
# Episode 165/10000, Total Reward: -3023.46
# Episode 166/10000, Total Reward: -3018.43
# Episode 167/10000, Total Reward: -3017.72
# Episode 168/10000, Total Reward: -1603.70
# Episode 169/10000, Total Reward: -3019.81
# Episode 170/10000, Total Reward: -1803.72
# Episode 171/10000, Total Reward: -1703.74
# Episode 172/10000, Total Reward: -3016.66
# Episode 173/10000, Total Reward: -3018.16
# Episode 174/10000, Total Reward: -3014.42
# Episode 175/10000, Total Reward: -1603.76
# Episode 176/10000, Total Reward: -3021.44
# Episode 177/10000, Total Reward: -3015.41
# Episode 178/10000, Total Reward: -3021.26
# Episode 179/10000, Total Reward: -3018.88
# Episode 180/10000, Total Reward: -3016.49
# Episode 181/10000, Total Reward: -3025.90
# Episode 182/10000, Total Reward: -1603.79
# Episode 183/10000, Total Reward: -3018.05
# Episode 184/10000, Total Reward: -3026.64
# Episode 185/10000, Total Reward: -3018.32
# Episode 186/10000, Total Reward: -3018.56
# Episode 187/10000, Total Reward: -1503.92
# Episode 188/10000, Total Reward: -3018.77
# Episode 189/10000, Total Reward: -3019.72
# Episode 190/10000, Total Reward: -1803.80
# Episode 191/10000, Total Reward: -3018.96
# Episode 192/10000, Total Reward: -1703.79
# Episode 193/10000, Total Reward: -1603.72
# Episode 194/10000, Total Reward: -3021.77
# Episode 195/10000, Total Reward: -3017.13
# Episode 196/10000, Total Reward: -1703.69
# Episode 197/10000, Total Reward: -3018.99
# Episode 198/10000, Total Reward: -3017.70
# Episode 199/10000, Total Reward: -3019.02
# Episode 200/10000, Total Reward: -3016.78
# Episode 201/10000, Total Reward: -3019.16
# Episode 202/10000, Total Reward: -3019.64
# Episode 203/10000, Total Reward: -1803.84
# Episode 204/10000, Total Reward: -3019.88
# Episode 205/10000, Total Reward: -1703.62
# Episode 206/10000, Total Reward: -3020.28
# Episode 207/10000, Total Reward: -3020.44
# Episode 208/10000, Total Reward: -1703.72
# Episode 209/10000, Total Reward: -1603.81
# Episode 210/10000, Total Reward: -1603.71
# Episode 211/10000, Total Reward: -1703.76
# Episode 212/10000, Total Reward: -3018.85
# Episode 213/10000, Total Reward: -3020.94
# Episode 214/10000, Total Reward: -3017.77
# Episode 215/10000, Total Reward: -1703.73
# Episode 216/10000, Total Reward: -3015.08
# Episode 217/10000, Total Reward: -3022.27
# Episode 218/10000, Total Reward: -3017.72
# Episode 219/10000, Total Reward: -1803.86
# Episode 220/10000, Total Reward: -1603.70
# Episode 221/10000, Total Reward: -3018.11
# Episode 222/10000, Total Reward: -3022.52
# Episode 223/10000, Total Reward: -3024.99
# Episode 224/10000, Total Reward: -3017.34
# Episode 225/10000, Total Reward: -3017.75
# Episode 226/10000, Total Reward: -1803.68
# Episode 227/10000, Total Reward: -3018.89
# Episode 228/10000, Total Reward: -1703.69
# Episode 229/10000, Total Reward: -3018.15
# Episode 230/10000, Total Reward: -3016.31
# Episode 231/10000, Total Reward: -3018.81
# Episode 232/10000, Total Reward: -3018.95
# Episode 233/10000, Total Reward: -3015.15
# Episode 234/10000, Total Reward: -1803.82
# Episode 235/10000, Total Reward: -3016.29
# Episode 236/10000, Total Reward: -3018.81
# Episode 237/10000, Total Reward: -3015.84
# Episode 238/10000, Total Reward: -3018.72
# Episode 239/10000, Total Reward: -3014.69
# Episode 240/10000, Total Reward: -3019.99
# Episode 241/10000, Total Reward: -3021.34
# Episode 242/10000, Total Reward: -1803.78
# Episode 243/10000, Total Reward: -1703.66
# Episode 244/10000, Total Reward: -1503.76
# Episode 245/10000, Total Reward: -1803.80
# Episode 246/10000, Total Reward: -3017.36
# Episode 247/10000, Total Reward: -1803.76
# Episode 248/10000, Total Reward: -3016.86
# Episode 249/10000, Total Reward: -1703.69
# Episode 250/10000, Total Reward: -3020.20
# Episode 251/10000, Total Reward: -3018.70
# Episode 252/10000, Total Reward: -3018.62
# Episode 253/10000, Total Reward: -3025.24
# Episode 254/10000, Total Reward: -3018.26
# Episode 255/10000, Total Reward: -1803.78
# Episode 256/10000, Total Reward: -3018.67
# Episode 257/10000, Total Reward: -1703.70
# Episode 258/10000, Total Reward: -1605.41
# Episode 259/10000, Total Reward: -3018.12
# Episode 260/10000, Total Reward: -3021.22
# Episode 261/10000, Total Reward: -1505.35
# Episode 262/10000, Total Reward: -3017.90
# Episode 263/10000, Total Reward: -1305.44
# Episode 264/10000, Total Reward: -3019.11
# Episode 265/10000, Total Reward: -3018.22
# Episode 266/10000, Total Reward: -3020.80
# Episode 267/10000, Total Reward: -1704.60
# Episode 268/10000, Total Reward: -1804.70
# Episode 269/10000, Total Reward: -3016.58
# Episode 270/10000, Total Reward: -3019.80
# Episode 271/10000, Total Reward: -1704.62
# Episode 272/10000, Total Reward: -1604.02
# Episode 273/10000, Total Reward: -1503.86
# Episode 274/10000, Total Reward: -3019.56
# Episode 275/10000, Total Reward: -1604.34
# Episode 276/10000, Total Reward: -3020.23
# Episode 277/10000, Total Reward: -1705.11
# Episode 278/10000, Total Reward: -1504.69
# Episode 279/10000, Total Reward: -3016.86
# Episode 280/10000, Total Reward: -3016.78
# Episode 281/10000, Total Reward: -1704.94
# Episode 282/10000, Total Reward: -1704.93
# Episode 283/10000, Total Reward: -3016.25
# Episode 284/10000, Total Reward: -3020.96
# Episode 285/10000, Total Reward: -3018.54
# Episode 286/10000, Total Reward: -3015.15
# Episode 287/10000, Total Reward: -3018.05
# Episode 288/10000, Total Reward: -3016.64
# Episode 289/10000, Total Reward: -1804.85
# Episode 290/10000, Total Reward: -3017.58
# Episode 291/10000, Total Reward: -3017.41
# Episode 292/10000, Total Reward: -3017.78
# Episode 293/10000, Total Reward: -3016.28
# Episode 294/10000, Total Reward: -3018.13
# Episode 295/10000, Total Reward: -3021.22
# Episode 296/10000, Total Reward: -3017.53
# Episode 297/10000, Total Reward: -3015.16
# Episode 298/10000, Total Reward: -3015.47
# Episode 299/10000, Total Reward: -3017.40
# Episode 300/10000, Total Reward: -3018.06
# Episode 301/10000, Total Reward: -3015.51
# Episode 302/10000, Total Reward: -3014.97
# Episode 303/10000, Total Reward: -3017.57
# Episode 304/10000, Total Reward: -3016.46
# Episode 305/10000, Total Reward: -3017.91
# Episode 306/10000, Total Reward: -3016.92
# Episode 307/10000, Total Reward: -3022.43
# Episode 308/10000, Total Reward: -1704.05
# Episode 309/10000, Total Reward: -1603.18
# Episode 310/10000, Total Reward: -1603.75
# Episode 311/10000, Total Reward: -1503.80
# Episode 312/10000, Total Reward: -1604.22
# Episode 313/10000, Total Reward: -3019.02
# Episode 314/10000, Total Reward: -3020.71
# Episode 315/10000, Total Reward: -3019.16
# Episode 316/10000, Total Reward: -1603.58
# Episode 317/10000, Total Reward: -3018.65
# Episode 318/10000, Total Reward: -1604.65
# Episode 319/10000, Total Reward: -3016.95
# Episode 320/10000, Total Reward: -1604.25
# Episode 321/10000, Total Reward: -1504.68
# Episode 322/10000, Total Reward: -3019.12
# Episode 323/10000, Total Reward: -3018.40
# Episode 324/10000, Total Reward: -3020.82
# Episode 325/10000, Total Reward: -1604.56
# Episode 326/10000, Total Reward: -1504.86
# Episode 327/10000, Total Reward: -3014.76
# Episode 328/10000, Total Reward: -3015.67
# Episode 329/10000, Total Reward: -1505.23
# Episode 330/10000, Total Reward: -3018.58
# Episode 331/10000, Total Reward: -3021.30
# Episode 332/10000, Total Reward: -3016.74
# Episode 333/10000, Total Reward: -3018.69
# Episode 334/10000, Total Reward: -3019.55
# Episode 335/10000, Total Reward: -3019.64
# Episode 336/10000, Total Reward: -1704.64
# Episode 337/10000, Total Reward: -1704.34
# Episode 338/10000, Total Reward: -3018.69
# Episode 339/10000, Total Reward: -3018.71
# Episode 340/10000, Total Reward: -1603.69
# Episode 341/10000, Total Reward: -3019.15
# Episode 342/10000, Total Reward: -3020.68
# Episode 343/10000, Total Reward: -1604.53
# Episode 344/10000, Total Reward: -3019.50
# Episode 345/10000, Total Reward: -1404.67
# Episode 346/10000, Total Reward: -3016.91
# Episode 347/10000, Total Reward: -3024.23
# Episode 348/10000, Total Reward: -3017.20
# Episode 349/10000, Total Reward: -3018.76
# Episode 350/10000, Total Reward: -3015.65
# Episode 351/10000, Total Reward: -1505.45
# Episode 352/10000, Total Reward: -3017.26
# Episode 353/10000, Total Reward: -3017.81
# Episode 354/10000, Total Reward: -3019.92
# Episode 355/10000, Total Reward: -3016.43
# Episode 356/10000, Total Reward: -1804.96
# Episode 357/10000, Total Reward: -3019.47
# Episode 358/10000, Total Reward: -3016.61
# Episode 359/10000, Total Reward: -1605.01
# Episode 360/10000, Total Reward: -3016.28
# Episode 361/10000, Total Reward: -1404.39
# Episode 362/10000, Total Reward: -1903.76
# Episode 363/10000, Total Reward: -1705.02
# Episode 364/10000, Total Reward: -3021.36
# Episode 365/10000, Total Reward: -3017.83
# Episode 366/10000, Total Reward: -3016.86
# Episode 367/10000, Total Reward: -3017.41
# Episode 368/10000, Total Reward: -3020.92
# Episode 369/10000, Total Reward: -3017.08
# Episode 370/10000, Total Reward: -3015.64
# Episode 371/10000, Total Reward: -1503.71
# Episode 372/10000, Total Reward: -3016.05
# Episode 373/10000, Total Reward: -1704.22
# Episode 374/10000, Total Reward: -3014.49
# Episode 375/10000, Total Reward: -3017.44
# Episode 376/10000, Total Reward: -1605.07
# Episode 377/10000, Total Reward: -3017.97
# Episode 378/10000, Total Reward: -3020.10
# Episode 379/10000, Total Reward: -1605.15
# Episode 380/10000, Total Reward: -3014.46
# Episode 381/10000, Total Reward: -1705.41
# Episode 382/10000, Total Reward: -3017.59
# Episode 383/10000, Total Reward: -3016.59
# Episode 384/10000, Total Reward: -1705.02
# Episode 385/10000, Total Reward: -1704.42
# Episode 386/10000, Total Reward: -3022.56
# Episode 387/10000, Total Reward: -3020.15
# Episode 388/10000, Total Reward: -3017.83
# Episode 389/10000, Total Reward: -3016.20
# Episode 390/10000, Total Reward: -3018.54
# Episode 391/10000, Total Reward: -1804.55
# Episode 392/10000, Total Reward: -1805.25
# Episode 393/10000, Total Reward: -3015.37
# Episode 394/10000, Total Reward: -3019.93
# Episode 395/10000, Total Reward: -1804.75
# Episode 396/10000, Total Reward: -1504.71
# Episode 397/10000, Total Reward: -3019.89
# Episode 398/10000, Total Reward: -1504.63
# Episode 399/10000, Total Reward: -3018.55
# Episode 400/10000, Total Reward: -3018.03
# Episode 401/10000, Total Reward: -3012.12
# Episode 402/10000, Total Reward: -1604.84
# Episode 403/10000, Total Reward: -2005.91
# Episode 404/10000, Total Reward: -1805.20
# Episode 405/10000, Total Reward: -1905.05
# Episode 406/10000, Total Reward: -3025.51
# Episode 407/10000, Total Reward: -3023.24
# Episode 408/10000, Total Reward: -3015.01
# Episode 409/10000, Total Reward: -1604.96
# Episode 410/10000, Total Reward: -3017.48
# Episode 411/10000, Total Reward: -1804.98
# Episode 412/10000, Total Reward: -1805.00
# Episode 413/10000, Total Reward: -1704.82
# Episode 414/10000, Total Reward: -3019.23
# Episode 415/10000, Total Reward: -3015.22
# Episode 416/10000, Total Reward: -3017.98
# Episode 417/10000, Total Reward: -2204.88
# Episode 418/10000, Total Reward: -1904.90
# Episode 419/10000, Total Reward: -3020.22
# Episode 420/10000, Total Reward: -3018.47
# Episode 421/10000, Total Reward: -3013.36
# Episode 422/10000, Total Reward: -1504.22
# Episode 423/10000, Total Reward: -1604.39
# Episode 424/10000, Total Reward: -1704.38
# Episode 425/10000, Total Reward: -3019.14
# Episode 426/10000, Total Reward: -3016.40
# Episode 427/10000, Total Reward: -3013.29
# Episode 428/10000, Total Reward: -1505.21
# Episode 429/10000, Total Reward: -1606.36
# Episode 430/10000, Total Reward: -3018.49
# Episode 431/10000, Total Reward: -1705.43
# Episode 432/10000, Total Reward: -2005.45
# Episode 433/10000, Total Reward: -3021.25
# Episode 434/10000, Total Reward: -1606.47
# Episode 435/10000, Total Reward: -3021.39
# Episode 436/10000, Total Reward: -3023.53
# Episode 437/10000, Total Reward: -3023.40
# Episode 438/10000, Total Reward: -3023.63
# Episode 439/10000, Total Reward: -1605.12
# Episode 440/10000, Total Reward: -1605.22
# Episode 441/10000, Total Reward: -1404.53
# Episode 442/10000, Total Reward: -3016.72
# Episode 443/10000, Total Reward: -3015.85
# Episode 444/10000, Total Reward: -1704.42
# Episode 445/10000, Total Reward: -3023.43
# Episode 446/10000, Total Reward: -1504.20
# Episode 447/10000, Total Reward: -1703.98
# Episode 448/10000, Total Reward: -1603.98
# Episode 449/10000, Total Reward: -3017.65
# Episode 450/10000, Total Reward: -3015.43
# Episode 451/10000, Total Reward: -3015.85
# Episode 452/10000, Total Reward: -1804.47
# Episode 453/10000, Total Reward: -3017.71
# Episode 454/10000, Total Reward: -3115.11
# Episode 455/10000, Total Reward: -3017.48
# Episode 456/10000, Total Reward: -3016.08
# Episode 457/10000, Total Reward: -3016.60
# Episode 458/10000, Total Reward: -3021.57
# Episode 459/10000, Total Reward: -1704.96
# Episode 460/10000, Total Reward: -3015.37
# Episode 461/10000, Total Reward: -3022.11
# Episode 462/10000, Total Reward: -1704.51
# Episode 463/10000, Total Reward: -3016.04
# Episode 464/10000, Total Reward: -3015.61
# Episode 465/10000, Total Reward: -1904.47
# Episode 466/10000, Total Reward: -3017.01
# Episode 467/10000, Total Reward: -3015.15
# Episode 468/10000, Total Reward: -1804.34
# Episode 469/10000, Total Reward: -1704.09
# Episode 470/10000, Total Reward: -3017.22
# Episode 471/10000, Total Reward: -1703.72
# Episode 472/10000, Total Reward: -3018.05
# Episode 473/10000, Total Reward: -3020.85
# Episode 474/10000, Total Reward: -3016.25
# Episode 475/10000, Total Reward: -1704.44
# Episode 476/10000, Total Reward: -1604.44
# Episode 477/10000, Total Reward: -3017.12
# Episode 478/10000, Total Reward: -3019.12
# Episode 479/10000, Total Reward: -3019.60
# Episode 480/10000, Total Reward: -3018.69
# Episode 481/10000, Total Reward: -3018.45
# Episode 482/10000, Total Reward: -1604.61
# Episode 483/10000, Total Reward: -1704.60
# Episode 484/10000, Total Reward: -3019.31
# Episode 485/10000, Total Reward: -3018.22
# Episode 486/10000, Total Reward: -1404.50
# Episode 487/10000, Total Reward: -3015.71
# Episode 488/10000, Total Reward: -3021.61
# Episode 489/10000, Total Reward: -3016.19
# Episode 490/10000, Total Reward: -1705.18
# Episode 491/10000, Total Reward: -1504.59
# Episode 492/10000, Total Reward: -3016.06
# Episode 493/10000, Total Reward: -1604.19
# Episode 494/10000, Total Reward: -3018.50
# Episode 495/10000, Total Reward: -3018.11
# Episode 496/10000, Total Reward: -3016.29
# Episode 497/10000, Total Reward: -1904.43
# Episode 498/10000, Total Reward: -1704.62
# Episode 499/10000, Total Reward: -3020.26
# Episode 500/10000, Total Reward: -3018.19
# Episode 501/10000, Total Reward: -2104.85
# Episode 502/10000, Total Reward: -3021.03
# Episode 503/10000, Total Reward: -3018.56
# Episode 504/10000, Total Reward: -1605.39
# Episode 505/10000, Total Reward: -3020.86
# Episode 506/10000, Total Reward: -1704.89
# Episode 507/10000, Total Reward: -3024.14
# Episode 508/10000, Total Reward: -1404.87
# Episode 509/10000, Total Reward: -3019.93
# Episode 510/10000, Total Reward: -1704.53
# Episode 511/10000, Total Reward: -3016.52
# Episode 512/10000, Total Reward: -1704.53
# Episode 513/10000, Total Reward: -3020.25
# Episode 514/10000, Total Reward: -1703.76
# Episode 515/10000, Total Reward: -3019.46
# Episode 516/10000, Total Reward: -3016.12
# Episode 517/10000, Total Reward: -3022.39
# Episode 518/10000, Total Reward: -1503.99
# Episode 519/10000, Total Reward: -1804.32
# Episode 520/10000, Total Reward: -3017.84
# Episode 521/10000, Total Reward: -1804.80
# Episode 522/10000, Total Reward: -1604.53
# Episode 523/10000, Total Reward: -1705.35
# Episode 524/10000, Total Reward: -3017.27
# Episode 525/10000, Total Reward: -1705.50
# Episode 526/10000, Total Reward: -3016.73
# Episode 527/10000, Total Reward: -1505.16
# Episode 528/10000, Total Reward: -3014.73
# Episode 529/10000, Total Reward: -1704.94
# Episode 530/10000, Total Reward: -3019.50
# Episode 531/10000, Total Reward: -1905.45
# Episode 532/10000, Total Reward: -3018.07
# Episode 533/10000, Total Reward: -1505.40
# Episode 534/10000, Total Reward: -1604.89
# Episode 535/10000, Total Reward: -3018.13
# Episode 536/10000, Total Reward: -1605.06
# Episode 537/10000, Total Reward: -3016.82
# Episode 538/10000, Total Reward: -1504.55
# Episode 539/10000, Total Reward: -3016.23
# Episode 540/10000, Total Reward: -3022.35
# Episode 541/10000, Total Reward: -3017.76
# Episode 542/10000, Total Reward: -3015.88
# Episode 543/10000, Total Reward: -3019.20
# Episode 544/10000, Total Reward: -3022.23
# Episode 545/10000, Total Reward: -1605.74
# Episode 546/10000, Total Reward: -3017.50
# Episode 547/10000, Total Reward: -1505.14
# Episode 548/10000, Total Reward: -3017.65
# Episode 549/10000, Total Reward: -3020.22
# Episode 550/10000, Total Reward: -3022.47
# Episode 551/10000, Total Reward: -3015.69
# Episode 552/10000, Total Reward: -1604.31
# Episode 553/10000, Total Reward: -3019.33
# Episode 554/10000, Total Reward: -1804.31
# Episode 555/10000, Total Reward: -3018.61
# Episode 556/10000, Total Reward: -3016.50
# Episode 557/10000, Total Reward: -3019.27
# Episode 558/10000, Total Reward: -1503.84
# Episode 559/10000, Total Reward: -3019.25
# Episode 560/10000, Total Reward: -3020.12
# Episode 561/10000, Total Reward: -3019.18
# Episode 562/10000, Total Reward: -3016.92
# Episode 563/10000, Total Reward: -2004.85
# Episode 564/10000, Total Reward: -1805.54
# Episode 565/10000, Total Reward: -1905.62
# Episode 566/10000, Total Reward: -3016.36
# Episode 567/10000, Total Reward: -3017.03
# Episode 568/10000, Total Reward: -3116.95
# Episode 569/10000, Total Reward: -1804.76
# Episode 570/10000, Total Reward: -3017.70
# Episode 571/10000, Total Reward: -1605.74
# Episode 572/10000, Total Reward: -1605.08
# Episode 573/10000, Total Reward: -3016.14
# Episode 574/10000, Total Reward: -1604.00
# Episode 575/10000, Total Reward: -1603.67
# Episode 576/10000, Total Reward: -3019.20
# Episode 577/10000, Total Reward: -1403.56
# Episode 578/10000, Total Reward: -3019.94
# Episode 579/10000, Total Reward: -3018.90
# Episode 580/10000, Total Reward: -1504.05
# Episode 581/10000, Total Reward: -1504.12
# Episode 582/10000, Total Reward: -3017.87
# Episode 583/10000, Total Reward: -1403.60
# Episode 584/10000, Total Reward: -1704.33
# Episode 585/10000, Total Reward: -3019.10
# Episode 586/10000, Total Reward: -1504.48
# Episode 587/10000, Total Reward: -3019.47
# Episode 588/10000, Total Reward: -3018.13
# Episode 589/10000, Total Reward: -2004.90
# Episode 590/10000, Total Reward: -1804.75
# Episode 591/10000, Total Reward: -1805.26
# Episode 592/10000, Total Reward: -1904.97
# Episode 593/10000, Total Reward: -1604.56
# Episode 594/10000, Total Reward: -3018.23
# Episode 595/10000, Total Reward: -1705.32
# Episode 596/10000, Total Reward: -1704.68
# Episode 597/10000, Total Reward: -3018.56
# Episode 598/10000, Total Reward: -3013.79
# Episode 599/10000, Total Reward: -1603.93
# Episode 600/10000, Total Reward: -3019.30
# Episode 601/10000, Total Reward: -3017.06
# Episode 602/10000, Total Reward: -1804.52
# Episode 603/10000, Total Reward: -1804.36
# Episode 604/10000, Total Reward: -3022.61
# Episode 605/10000, Total Reward: -3016.30
# Episode 606/10000, Total Reward: -1504.24
# Episode 607/10000, Total Reward: -1604.09
# Episode 608/10000, Total Reward: -3020.27
# Episode 609/10000, Total Reward: -3023.58
# Episode 610/10000, Total Reward: -3020.88
# Episode 611/10000, Total Reward: -3020.65
# Episode 612/10000, Total Reward: -3019.26
# Episode 613/10000, Total Reward: -1905.16
# Episode 614/10000, Total Reward: -3020.45
# Episode 615/10000, Total Reward: -1605.24
# Episode 616/10000, Total Reward: -1605.27
# Episode 617/10000, Total Reward: -3018.12
# Episode 618/10000, Total Reward: -1705.19
# Episode 619/10000, Total Reward: -3019.53
# Episode 620/10000, Total Reward: -1805.13
# Episode 621/10000, Total Reward: -1604.74
# Episode 622/10000, Total Reward: -3015.64
# Episode 623/10000, Total Reward: -3021.24
# Episode 624/10000, Total Reward: -3015.37
# Episode 625/10000, Total Reward: -1504.02
# Episode 626/10000, Total Reward: -1604.67
# Episode 627/10000, Total Reward: -1604.85
# Episode 628/10000, Total Reward: -3020.37
# Episode 629/10000, Total Reward: -1404.99
# Episode 630/10000, Total Reward: -1705.28
# Episode 631/10000, Total Reward: -3016.35
# Episode 632/10000, Total Reward: -3020.14
# Episode 633/10000, Total Reward: -3019.48
# Episode 634/10000, Total Reward: -1805.74
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 44
#      42 # Learn from experience
#      43 if agent.memory.size() > batch_size:
# ---> 44     critic_loss, actor_loss = agent.learn()
#      45     critic_losses.append(critic_loss)
#      46     actor_losses.append(actor_loss)
#
# Cell In[52], line 110, in DDPGAgent.learn(self)
#     108 # Target actions and Q-values
#     109 target_actions = self.target_actor.forward(states_)
# --> 110 critic_value_ = self.target_critic.forward(states_, target_actions)
#     111 critic_value = self.critic.forward(states, actions)
#     113 # Compute target value
#
# Cell In[50], line 104, in CriticNetwork.forward(self, states, actions)
#     102 # Compute embeddings for the current state's microservice graph and edge network graph
#     103 ms_embedding = self.ms_gnn(ms_graph.x, ms_graph.edge_index).mean(dim=0, keepdim=True)
# --> 104 edge_embedding = self.edge_network_gnn(edge_network.x, edge_network.edge_index).mean(dim=0, keepdim=True)
#     106 ms_embeddings.append(ms_embedding)
#     107 edge_embeddings.append(edge_embedding)
#
# File ~/.conda/envs/phd/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/phd/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[48], line 12, in GNNEncoder.forward(self, x, edge_index)
#      10 x = self.conv1(x, edge_index)
#      11 x = torch.relu(x)
# ---> 12 x = self.conv2(x, edge_index)
#      13 return x
#
# File ~/.conda/envs/phd/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/phd/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.conda/envs/phd/lib/python3.10/site-packages/torch_geometric/nn/conv/gcn_conv.py:241, in GCNConv.forward(self, x, edge_index, edge_weight)
#     239 cache = self._cached_edge_index
#     240 if cache is None:
# --> 241     edge_index, edge_weight = gcn_norm(  # yapf: disable
#     242         edge_index, edge_weight, x.size(self.node_dim),
#     243         self.improved, self.add_self_loops, self.flow, x.dtype)
#     244     if self.cached:
#     245         self._cached_edge_index = (edge_index, edge_weight)
#
# File ~/.conda/envs/phd/lib/python3.10/site-packages/torch_geometric/nn/conv/gcn_conv.py:108, in gcn_norm(edge_index, edge_weight, num_nodes, improved, add_self_loops, flow, dtype)
#     106 row, col = edge_index[0], edge_index[1]
#     107 idx = col if flow == 'source_to_target' else row
# --> 108 deg = scatter(edge_weight, idx, dim=0, dim_size=num_nodes, reduce='sum')
#     109 deg_inv_sqrt = deg.pow_(-0.5)
#     110 deg_inv_sqrt.masked_fill_(deg_inv_sqrt == float('inf'), 0)
#
# File ~/.conda/envs/phd/lib/python3.10/site-packages/torch_geometric/utils/_scatter.py:75, in scatter(src, index, dim, dim_size, reduce)
#      73 if reduce == 'sum' or reduce == 'add':
#      74     index = broadcast(index, src, dim)
# ---> 75     return src.new_zeros(size).scatter_add_(dim, index, src)
#      77 if reduce == 'mean':
#      78     count = src.new_zeros(dim_size)
#
# KeyboardInterrupt:

# %%
episodes = range(1, len(rewards_history) + 1)
steps = range(1, len(critic_losses) + 1)

# Plot rewards per episode
plt.figure(figsize=(10, 6))
plt.plot(episodes, rewards_history, label="Rewards", marker='o')
plt.title("Rewards Per Episode")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.grid()
plt.legend()
plt.show()

# %%
# Plot critic loss per step
plt.figure(figsize=(10, 6))
plt.plot(steps, critic_losses, label="Critic Loss", color="red", alpha=0.7)
plt.title("Critic Loss Per Step")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.grid()
plt.legend()
plt.show()

# %%
# Plot actor loss per step
plt.figure(figsize=(10, 6))
plt.plot(steps, actor_losses, label="Actor Loss", color="blue", alpha=0.7)
plt.title("Actor Loss Per Step")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.grid()
plt.legend()
plt.show()
